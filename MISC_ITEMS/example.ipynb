# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [10, 20, 15])
plt.title("Test Plot in Cursor Notebook")
plt.show()

# %%
message = "Hello from Cursor + Jupyter!"
message
# Out:
# 'Hello from Cursor + Jupyter!'

# %% [markdown]
# # Test Notebook
#
# This notebook demonstrates that Jupyter notebooks run correctly inside Cursor.
